# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets  # Example, importing datasets module
import tensorflow as tf
import torch
import keras
import scipy
import statsmodels
import vitaldb as vt
import ipywidgets as widgets
import ipympl    
# %matplotlib widget


print("Libraries Imported")
# Out:
# Libraries Imported

# %% [markdown]
# This dataset contains high-resolution multi-parameter data from 6,388 cases, including 486,451 waveform and numeric data tracks of 196 intraoperative monitoring parameters, 73 perioperative clinical parameters, and 34 time-series laboratory result parameters.

# %%
# Load the signal
signal_ppg = vt.load_case(1,['SNUADC/PLETH'], interval = 1/100)

# Generate the x values (number of samples)
samples_ppg = range(len(signal_ppg))

#print check
print(signal_ppg)
print(samples_ppg)
print(signal_ppg[:10])
print(len(signal_ppg))
print(type(signal_ppg))
print(signal_ppg.size)

# Plot the signal
plt.figure(figsize=(10, 6))
plt.plot(samples_ppg, signal_ppg)
plt.title("Signal Over Number of Samples")
plt.xlabel("Sample")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
# Out:
# [[        nan]
#  [        nan]
#  [        nan]
#  ...
#  [13.46039963]
#  [-5.49878979]
#  [        nan]]
# range(0, 1154111)
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 1154111
# <class 'numpy.ndarray'>
# 1154111
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the signal
signal_ecg = vt.load_case(1,['SNUADC/ECG_II'], interval = 1/100)

# Generate the x values (number of samples)
samples_ecg = range(len(signal_ecg))

#print check
print(signal_ecg)
print(samples_ecg)
print(signal_ecg[:10])
print(len(signal_ecg))
print(type(signal_ecg))
print(signal_ecg.size)

# Plot the signal
plt.figure(figsize=(10, 6))
plt.plot(samples_ecg, signal_ecg)
plt.title("Signal Over Number of Samples")
plt.xlabel("Sample")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
# Out:
# [[        nan]
#  [        nan]
#  [        nan]
#  ...
#  [ 0.148893  ]
#  [-0.32508701]
#  [        nan]]
# range(0, 1154111)
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# 1154111
# <class 'numpy.ndarray'>
# 1154111
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the signal
signal_body_temp1 = vt.load_case(1,['Solar8000/HR'], interval = 5)

# Generate the x values (number of samples)
samples_body_temp1 = range(len(signal_body_temp1))

#print check
print(signal_body_temp1)
print(samples_body_temp1)
print(signal_body_temp1[:10])
print(len(signal_body_temp1))
print(type(signal_body_temp1))
print(signal_body_temp1.size)


# Plot the signal
plt.figure(figsize=(10, 6))
plt.plot(samples_body_temp1, signal_body_temp1)
plt.title("Signal Over Number of Samples")
plt.xlabel("Sample")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
# Out:
# [[ 87.]
#  [ 88.]
#  [ 89.]
#  ...
#  [103.]
#  [103.]
#  [103.]]
# range(0, 2189)
# [[87.]
#  [88.]
#  [89.]
#  [79.]
#  [79.]
#  [78.]
#  [nan]
#  [nan]
#  [78.]
#  [78.]]
# 2189
# <class 'numpy.ndarray'>
# 2189
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the signal
signal_body_temp = vt.load_case(1,['Solar8000/PLETH_HR'], interval = 5)

# Generate the x values (number of samples)
samples_body_temp = range(len(signal_body_temp))

#print check
print(signal_body_temp)
print(samples_body_temp)
print(signal_body_temp[:10])
print(len(signal_body_temp))
print(type(signal_body_temp))
print(signal_body_temp.size)


# Plot the signal
plt.figure(figsize=(10, 6))
plt.plot(samples_body_temp, signal_body_temp)
plt.title("Signal Over Number of Samples")
plt.xlabel("Sample")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
# Out:
# [[ 88.]
#  [ 89.]
#  [ 89.]
#  ...
#  [ nan]
#  [ nan]
#  [270.]]
# range(0, 2291)
# [[88.]
#  [89.]
#  [89.]
#  [89.]
#  [86.]
#  [87.]
#  [88.]
#  [87.]
#  [86.]
#  [87.]]
# 2291
# <class 'numpy.ndarray'>
# 2291
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the signal
signal_body_temp2 = vt.load_case(1,['Solar8000/BT'], interval = 10)

# Generate the x values (number of samples)
samples_body_temp2 = range(len(signal_body_temp2))

#print check
print(signal_body_temp2)
print(samples_body_temp2)
print(signal_body_temp2[:10])
print(len(signal_body_temp2))
print(type(signal_body_temp2))
print(signal_body_temp2.size)


# Plot the signal
plt.figure(figsize=(10, 6))
plt.plot(samples_body_temp2, signal_body_temp2)
plt.title("Signal Over Number of Samples")
plt.xlabel("Sample")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
# Out:
# [[21.        ]
#  [21.        ]
#  [21.        ]
#  ...
#  [21.60000038]
#  [21.5       ]
#  [21.5       ]]
# range(0, 1155)
# [[21.        ]
#  [21.        ]
#  [21.        ]
#  [21.        ]
#  [21.        ]
#  [21.        ]
#  [21.        ]
#  [21.        ]
#  [21.10000038]
#  [21.        ]]
# 1155
# <class 'numpy.ndarray'>
# 1155
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the signal
signal_body_temp3 = vt.load_case(1,['Solar8000/RR'], interval = 100)

# Generate the x values (number of samples)
samples_body_temp3 = range(len(signal_body_temp3))

#print check
print(signal_body_temp3)
print(samples_body_temp3)
print(signal_body_temp3[:10])
print(len(signal_body_temp3))
print(type(signal_body_temp3))
print(signal_body_temp3.size)


# Plot the signal
plt.figure(figsize=(10, 6))
plt.plot(samples_body_temp3, signal_body_temp3)
plt.title("Signal Over Number of Samples")
plt.xlabel("Sample")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
# Out:
# []
# range(0, 0)
# []
# 0
# <class 'numpy.ndarray'>
# 0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
