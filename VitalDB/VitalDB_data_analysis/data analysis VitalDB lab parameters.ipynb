# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets  # Example, importing datasets module
import tensorflow as tf
import torch
import keras
import scipy
import statsmodels
import vitaldb as vt
import ipywidgets as widgets
import ipympl
# %matplotlib widget


print("Libraries Imported")
# Out:
# Libraries Imported

# %%
df_vitalDB_lab_parameters = pd.read_csv('C:\\Users\\20181588\\Desktop\\data\\vitaldb-a-high-fidelity-multi-parameter-vital-signs-database-in-surgical-patients-1.0.0\\vitaldb-a-high-fidelity-multi-parameter-vital-signs-database-in-surgical-patients-1.0.0\\lab_parameters.csv')

# %%
df_vitalDB_lab_parameters.head(30)
# Out:
#    Parameter     Category                            Description  \
# 0        wbc          CBC                 White blood cell count
# 1         hb          CBC                             Hemoglobin
# 2        hct          CBC                             Hematocrit
# 3        plt          CBC                         Platelet count
# 4        esr          CBC         Erythrocyte sedimentation rate
# 5       gluc    Chemistry                                Glucose
# 6      tprot    Chemistry                          Total protein
# 7        alb    Chemistry                                Albumin
# 8       tbil    Chemistry                        Total bilirubin
# 9        ast    Chemistry                   Asparate transferase
# 10       alt    Chemistry                    Alanine transferase
# 11       bun    Chemistry                    Blood urea nitrogen
# 12        cr    Chemistry                             Creatinine
# ...

# %%
df_vitalDB_lab_parameters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Parameter        33 non-null     object
#  1   Category         33 non-null     object
#  2   Description      33 non-null     object
#  3   Unit             32 non-null     object
#  4   Reference value  33 non-null     object
# dtypes: object(5)
# memory usage: 1.4+ KB
