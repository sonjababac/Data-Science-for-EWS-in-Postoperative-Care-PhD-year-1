# %% [markdown]
# <h1 style="font-size:36px;">Data exploration of INSPIRE, a publicly available research dataset for perioperative medicine</h1>
#
# <h2 style="font-size:20px;">In this script data exploration and analysis of ""parameters.csv" is shown</h2>
#
# link: https://physionet.org/content/inspire/0.1/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets  # Example, importing datasets module
import tensorflow as tf
import torch
import keras
import scipy
import statsmodels

print("Libraries Imported")
# Out:
# Libraries Imported

# %%
df_parameters = pd.read_csv('C:\\Users\\20181588\\Desktop\\data\\inspire-a-publicly-available-research-dataset-for-perioperative-medicine-1.0\\inspire-a-publicly-available-research-dataset-for-perioperative-medicine-1.0\\parameters.csv')

# %%
df_parameters.head(30)
# Out:
#    Table       Label    Unit  \
# 0   labs     albumin    g/dL
# 1   labs         alp    IU/L
# 2   labs         alt    IU/L
# 3   labs        aptt     sec
# 4   labs         ast    IU/L
# 5   labs          be  mmol/L
# 6   labs         bun   mg/dL
# 7   labs     calcium   mg/dL
# 8   labs    chloride  mmol/L
# 9   labs          ck    ug/L
# 10  labs        ckmb    ug/L
# 11  labs  creatinine   mg/dL
# 12  labs         crp   mg/dL
# 13  labs     d_dimer    mg/L
# 14  labs  fibrinogen   mg/dL
# 15  labs     glucose   mg/dL
# 16  labs          hb    g/dL
# 17  labs       hba1c       %
# 18  labs        hco3  mmol/L
# 19  labs         hct       %
# 20  labs      lacate  mmol/L
# 21  labs  lymphocyte     /ng
# 22  labs       paco2    mmHg
# 23  labs        pao2    mmHg
# 24  labs          ph     NaN
# 25  labs  phosphorus   mg/dL
# 26  labs    platelet     /nL
# 27  labs   potassium  mmol/L
# 28  labs       ptinr     INR
# 29  labs        sao2       %
#
#                                           Description
# 0                                             Albumin
# 1                                Alkaline phosphatase
# 2                                Alanine transaminase
# 3               Activated partial thromboplastin time
# 4                              Aspartate transaminase
# 5          Base excess in arterial blood gas analysis
# 6                                 Blood urea nitrogen
# 7                                             Calcium
# 8                                            Chloride
# 9                                     Creatine kinase
# 10                                 Creatine kinase-MB
# 11                                         Creatinine
# 12                                 High-sensitive CRP
# 13                                            D-dimer
# 14                                         Fibrinogen
# 15                                            Glucose
# 16                                         Hemoglobin
# 17                                     Hemoglobin A1c
# 18                HCO3 in arterial blood gas analysis
# 19                                         Hematocrit
# 20                                            Lactate
# 21                                   Lymphocyte count
# 22  Partial pressure of carbon dioxide in arterial...
# 23  Partial pressure of oxygen in arterial blood g...
# 24                  pH in arterial blood gas analysis
# 25                                         Phosphorus
# 26                                     Platelet count
# 27                                          Potassium
# 28                                   Prothrombin time
# 29   Oxygen saturation in arterial blood gas analysis

# %%
df_parameters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Table        118 non-null    object
#  1   Label        118 non-null    object
#  2   Unit         116 non-null    object
#  3   Description  118 non-null    object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
df_parameters.describe()
# Out:
#          Table Label  Unit                   Description
# count      118   118   116                           118
# unique       3   111    27                           112
# top     vitals    hr  mmHg  Peripheral oxygen saturation
# freq        71     2    16                             2

# %%
df_parameters.columns
# Out:
# Index(['Table', 'Label', 'Unit', 'Description'], dtype='object')
